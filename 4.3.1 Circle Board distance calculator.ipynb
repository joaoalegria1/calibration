# %% [markdown]
# # 4.1.1 Camera calibration

# %%
vscode = 1

# %%
if(vscode == 1):
    # for vscode
    # %matplotlib qt
else:
    # for jupyter notebook
    from mpl_toolkits.mplot3d import axes3d
    import matplotlib.pyplot as plt

    # %matplotlib notebook

# %%
import matplotlib.pyplot as plt
import numpy as np
import cv2 
from typing import Sequence
from calib_lib import *
DECIMALS = 2  # how many decimal places to use in print

# %% [markdown]
# ## Calculation of the 2D points

# %%
F = 16                                       # focal length( in mm )
image_size = np.array([1936,1216])               # sensor size(in mm)
pixel_width = 5.86e-3                       # pixel size in mm
PX= image_size[0]/2.0                       # principal point x-coordinate
PY= image_size[1]/2.0                       # principal point y-coordinate
IMAGE_HEIGTH = image_size[1]
IMAGE_WIDTH = image_size[0]
THETA_X = 0                                 # roll angle
THETA_Y = 0                                 # pitch angle
THETA_Z = 0                                 # yaw angle


# camera Right
THETA_X_R = 0                                 # roll angle
THETA_Y_R = 0                                 # pitch angle
THETA_Z_R= 0                                 # yaw angle
# camera Left
THETA_X_L = 0                                 # roll angle
THETA_Y_L = 0                                 # pitch angle
THETA_Z_L= 0                                 # yaw angle

C_L = np.array([0,0,0])                     # camera centre

C_R = np.array([500,0,0])

chess_dimx,chess_dimy = (12,8)
chess_sq_size = 44

# %%
P_L_original_p = [np.array([[2.73037543e+03, 0.00000000e+00, 9.68000000e+02, 0.00000000e+00],
                        [0.00000000e+00, 2.73037543e+03, 6.08000000e+02, 0.00000000e+00],
                        [0.00000000e+00, 0.00000000e+00, 1.00000000e+00, 0.00000000e+00]]),
                np.array([[2.73037543e+03, 0.00000000e+00, 9.68000000e+02, 0.00000000e+00],
                        [0.00000000e+00, 2.73037543e+03, 6.08000000e+02, 0.00000000e+00],
                        [0.00000000e+00, 0.00000000e+00, 1.00000000e+00, 0.00000000e+00]]),
                np.array([[2.73037543e+03, 0.00000000e+00, 9.68000000e+02, 0.00000000e+00],
                        [0.00000000e+00, 2.73037543e+03, 6.08000000e+02, 0.00000000e+00],
                        [0.00000000e+00, 0.00000000e+00, 1.00000000e+00, 0.00000000e+00]]),
                np.array([[2.73037543e+03, 0.00000000e+00, 9.68000000e+02, 0.00000000e+00],
                        [0.00000000e+00, 2.73037543e+03, 6.08000000e+02, 0.00000000e+00],
                        [0.00000000e+00, 0.00000000e+00, 1.00000000e+00, 0.00000000e+00]]),
                np.array([[2.73037543e+03, 0.00000000e+00, 9.68000000e+02, 0.00000000e+00],
                        [0.00000000e+00, 2.73037543e+03, 6.08000000e+02, 0.00000000e+00],
                        [0.00000000e+00, 0.00000000e+00, 1.00000000e+00, 0.00000000e+00]]),
                np.array([[2.73037543e+03, 0.00000000e+00, 9.68000000e+02, 0.00000000e+00],
                        [0.00000000e+00, 2.73037543e+03, 6.08000000e+02, 0.00000000e+00],
                        [0.00000000e+00, 0.00000000e+00, 1.00000000e+00, 0.00000000e+00]])]

# %%
P_R_original_p =  [np.array([[ 2.73037543e+03,  0.00000000e+00,9.68000000e+02,-1.36518771e+06],
                        [ 0.00000000e+00,  2.73037543e+03,  6.08000000e+02,0.00000000e+00],
                        [ 0.00000000e+00,  0.00000000e+00,  1.00000000e+00,0.00000000e+00]]),
                np.array([[ 2.73037543e+03,  0.00000000e+00,  9.68000000e+02,-1.36518771e+06],
                        [ 0.00000000e+00,  2.73037543e+03,  6.08000000e+02,0.00000000e+00],
                        [ 0.00000000e+00,  0.00000000e+00,  1.00000000e+00,0.00000000e+00]]),
                np.array([[ 2.73037543e+03,  0.00000000e+00,  9.68000000e+02,-1.36518771e+06],
                        [ 0.00000000e+00,  2.73037543e+03,  6.08000000e+02,0.00000000e+00],
                        [ 0.00000000e+00,  0.00000000e+00,  1.00000000e+00,0.00000000e+00]]),
                np.array([[ 2.73037543e+03,  0.00000000e+00,  9.68000000e+02,-1.36518771e+06],
                        [ 0.00000000e+00,  2.73037543e+03,  6.08000000e+02,0.00000000e+00],
                        [ 0.00000000e+00,  0.00000000e+00,  1.00000000e+00,0.00000000e+00]]),
                np.array([[ 2.73037543e+03,  0.00000000e+00,  9.68000000e+02,-1.36518771e+06],
                        [ 0.00000000e+00,  2.73037543e+03,  6.08000000e+02,0.00000000e+00],
                        [ 0.00000000e+00,  0.00000000e+00,  1.00000000e+00,0.00000000e+00]]),
                np.array([[ 2.73037543e+03,  0.00000000e+00,  9.68000000e+02,-1.36518771e+06],
                        [ 0.00000000e+00,  2.73037543e+03,  6.08000000e+02,0.00000000e+00],
                        [ 0.00000000e+00,  0.00000000e+00,  1.00000000e+00,0.00000000e+00]])]

# %%
ret_S_2_p = [[0.2637375195395553],
             [0.5208904811475614],
             [0.39595311339867384],
             [0.4774205929812345],
             [0.5403807164757266],
             [0.5129051705850326]]

ret_S_3_p = [[0.6444367035996724],
             [0.6974252709552935],
             [0.573508528650511],
             [0.665329407548191],
             [0.5727506628172644],
             [0.5066560423117088]]

ret_S_4_p = [[0.11495297071858447],
             [0.4353682960725999],
             [0.33533863107822903],
             [0.2932726745717978],
             [0.3074331716408665],
             [0.4381999154429301]]

# %%
new_mtxL_list_2_p =     [[np.array([[3177.394344, 0.000000, 868.514520],
                                [0.000000, 3193.865542, 613.104839],
                                [0.000000, 0.000000, 1.000000]])],
                        [np.array([[2601.802800, 0.000000, 913.720774],
                                [0.000000, 2603.661860, 640.282020],
                                [0.000000, 0.000000, 1.000000]])],
                        [np.array([[2590.965467, 0.000000, 907.098782],
                                [0.000000, 2595.823358, 621.646273],
                                [0.000000, 0.000000, 1.000000]])],
                        [np.array([[2619.382584, 0.000000, 908.967047],
                                [0.000000, 2622.730112, 606.658303],
                                [0.000000, 0.000000, 1.000000]])],
                        [np.array([[2585.978443, 0.000000, 942.514399],
                                [0.000000, 2588.592868, 594.521434],
                                [0.000000, 0.000000, 1.000000]])],
                        [np.array([[2574.733760, 0.000000, 946.084130],
                                [0.000000, 2577.776040, 590.873339],
                                [0.000000, 0.000000, 1.000000]])]] 

new_mtxL_list_3_p =     [[np.array([[2.56358996e+03, 0.00000000e+00, 9.00413244e+02],
                                [0.00000000e+00, 2.55836987e+03, 5.95131659e+02],
                                [0.00000000e+00, 0.00000000e+00, 1.00000000e+00]])],
                        [np.array([[2.57159779e+03, 0.00000000e+00, 8.79677473e+02],
                                [0.00000000e+00, 2.56448675e+03, 6.20432029e+02],
                                [0.00000000e+00, 0.00000000e+00, 1.00000000e+00]])],
                        [np.array([[2.56141720e+03, 0.00000000e+00, 9.03328715e+02],
                                [0.00000000e+00, 2.55833609e+03, 6.11736763e+02],
                                [0.00000000e+00, 0.00000000e+00, 1.00000000e+00]])],
                        [np.array([[2.56739511e+03, 0.00000000e+00, 9.07042600e+02],
                                [0.00000000e+00, 2.56017541e+03, 6.03841330e+02],
                                [0.00000000e+00, 0.00000000e+00, 1.00000000e+00]])],
                        [np.array([[2546.944320, 0.000000, 925.728803],
                                [0.000000, 2545.877929, 594.959136],
                                [0.000000, 0.000000, 1.000000]])],
                        [np.array([[2543.759607, 0.000000, 920.626093],
                                [0.000000, 2543.153247, 593.669771],
                                [0.000000, 0.000000, 1.000000]])]]                                  

new_mtxL_list_4_p =     [[np.array([[2471.269294, 0.000000, 909.453470],
                                [0.000000, 2458.434752, 628.586125],
                                [0.000000, 0.000000, 1.000000]])],
                        [np.array([[2492.730191, 0.000000, 937.868012],
                                [0.000000, 2453.419376, 607.329803],
                                [0.000000, 0.000000, 1.000000]])],
                        [np.array([[2377.283484, 0.000000, 899.953008],
                                [0.000000, 2367.931216, 640.622319],
                                [0.000000, 0.000000, 1.000000]])],
                        [np.array([[2296.716257, 0.000000, 915.489948],
                                [0.000000, 2296.994123, 619.468668],
                                [0.000000, 0.000000, 1.000000]])],
                        [np.array([[2313.198140, 0.000000, 936.749683],
                                [0.000000, 2312.726330, 634.529867],
                                [0.000000, 0.000000, 1.000000]])],
                        [np.array([[2660.339510, 0.000000, 917.221163],
                                [0.000000, 2662.833935, 619.250302],
                                [0.000000, 0.000000, 1.000000]])]]

# %%
ret_L_list_2_p =    [[0.17196515935514858],
                    [0.47863845277104067],
                    [0.36123020670433137],
                    [0.44011645068186067],
                    [0.4872057983230428],
                    [0.4672643081187851]]

ret_L_list_3_p =    [[0.6067080727105552],
                    [0.6574520960736969],
                    [0.5338728359408561],
                    [0.5742361284592391],
                    [0.48220078216376067],
                    [0.42299196053794874]]

ret_L_list_4_p =    [[0.08575734649873147],
                    [0.3167756093700254],
                    [0.26277033422482515],
                    [0.22998670447853434],
                    [0.21317684936216882],
                    [0.20820309169589335]]

# %%
new_mtxR_list_2_p =     [[np.array([[2740.523940, 0.000000, 1011.343989],
                                [0.000000, 2745.916176, 673.805539],
                                [0.000000, 0.000000, 1.000000]])],
                        [np.array([[2605.435065, 0.000000, 1000.655553],
                                [0.000000, 2607.384771, 677.607012],
                                [0.000000, 0.000000, 1.000000]])],
                        [np.array([[2606.595357, 0.000000, 989.407340],
                                [0.000000, 2609.168364, 657.813164],
                                [0.000000, 0.000000, 1.000000]])],
                        [np.array([[2641.709842, 0.000000, 995.427222],
                                [0.000000, 2646.217062, 635.580703],
                                [0.000000, 0.000000, 1.000000]])],
                        [np.array([[2579.183470, 0.000000, 999.864075],
                                [0.000000, 2582.098697, 627.927045],
                                [0.000000, 0.000000, 1.000000]])],
                        [np.array([[2568.956315, 0.000000, 1000.924975],
                                [0.000000, 2572.199945, 625.579566],
                                [0.000000, 0.000000, 1.000000]])]]
                        
new_mtxR_list_3_p =     [[np.array([[ 9.97793158e-01,  6.38714110e-03, -6.60909825e-02],
                                [-6.44880157e-03,  9.99978947e-01, -7.19666375e-04],
                                [ 6.60849945e-02,  1.14428582e-03,  9.97813341e-01]])],
                        [np.array([[2.56835381e+03, 0.00000000e+00, 9.73932138e+02],
                                [0.00000000e+00, 2.56726682e+03, 6.45708931e+02],
                                [0.00000000e+00, 0.00000000e+00, 1.00000000e+00]])],
                        [np.array([[2.55806726e+03, 0.00000000e+00, 9.81954052e+02],
                                [0.00000000e+00, 2.56132169e+03, 6.37192983e+02],
                                [0.00000000e+00, 0.00000000e+00, 1.00000000e+00]])],
                        [np.array([[2.56343044e+03, 0.00000000e+00, 9.49654543e+02],
                                [0.00000000e+00, 2.56527639e+03, 6.29615996e+02],
                                [0.00000000e+00, 0.00000000e+00, 1.00000000e+00]])],
                        [np.array([[2553.923857, 0.000000, 969.112990],
                                [0.000000, 2556.833857, 623.886753],
                                [0.000000, 0.000000, 1.000000]])],
                        [np.array([[2546.185286, 0.000000, 969.790541],
                                [0.000000, 2549.933375, 621.862121],
                                [0.000000, 0.000000, 1.000000]])]]

new_mtxR_list_4_p =     [[np.array([[2781.431909, 0.000000, 872.800124],
                                [0.000000, 2777.377444, 666.324585],
                                [0.000000, 0.000000, 1.000000]])],
                        [np.array([[2432.871800, 0.000000, 959.041214],
                                [0.000000, 2434.751553, 751.074855],
                                [0.000000, 0.000000, 1.000000]])],
                        [np.array([[2435.038898, 0.000000, 942.247178],
                                [0.000000, 2435.674880, 714.132299],
                                [0.000000, 0.000000, 1.000000]])],
                        [np.array([[2394.869886, 0.000000, 916.504805],
                                [0.000000, 2393.080034, 654.922188],
                                [0.000000, 0.000000, 1.000000]])],
                        [np.array([[2408.760172, 0.000000, 930.011570],
                                [0.000000, 2407.142251, 668.685677],
                                [0.000000, 0.000000, 1.000000]])],
                        [np.array([[2414.717710, 0.000000, 940.417138],
                                [0.000000, 2414.074344, 664.689731],
                                [0.000000, 0.000000, 1.000000]])]]

# %%
ret_R_list_2_p =    [[0.2156546707277009],      
                    [0.5060286563587989],
                    [0.3797317627153738],
                    [0.47441006626612464],
                    [0.5218551163958846],
                    [0.4851207604596431]]

ret_R_list_3_p =    [[0.5919088397195084],      
                    [0.653565407611631],
                    [0.5401694328472426],
                    [0.5617705132959867],
                    [0.4744411668357235],
                    [0.4168205806424714]]

ret_R_list_4_p =    [[0.10576985026351769],      
                    [0.3000277156097531],
                    [0.2583356218070538],
                    [0.22229355425784175],
                    [0.20512449590031978],
                    [0.19110646351938845]]

# %%
Rot_list_2_p =  [[np.array([[0.998009, 0.001370, -0.063064],
                            [-0.001795, 0.999976, -0.006681],
                            [0.063053, 0.006781, 0.997987]])],
                [np.array([[0.998257, 0.002625, -0.058951],
                            [-0.002297, 0.999982, 0.005621],
                            [0.058965, -0.005476, 0.998245]])],
                [np.array([[0.998206, 0.003594, -0.059765],
                            [-0.003167, 0.999969, 0.007237],
                            [0.059790, -0.007035, 0.998186]])],
                [np.array([[0.998325, 0.003811, -0.057737],
                            [-0.003302, 0.999955, 0.008916],
                            [0.057769, -0.008710, 0.998292]])],
                [np.array([[0.998593, 0.004110, -0.052868],
                            [-0.003729, 0.999966, 0.007303],
                            [0.052897, -0.007095, 0.998575]])],
                [np.array([[0.998581, 0.004217, -0.053089],
                            [-0.003844, 0.999967, 0.007113],
                            [0.053117, -0.006899, 0.998564]])]]


Rot_list_3_p =  [[np.array([[ 9.97793158e-01,  6.38714110e-03, -6.60909825e-02],
                            [-6.44880157e-03,  9.99978947e-01, -7.19666375e-04],
                            [ 6.60849945e-02,  1.14428582e-03,  9.97813341e-01]])],
                [np.array([[ 9.96275246e-01,  6.51261201e-03, -8.59838383e-02],
                            [-6.42488023e-03,  9.99978519e-01,  1.29702253e-03],
                            [ 8.59904383e-02, -7.39755581e-04,  9.96295688e-01]])],
                [np.array([[ 9.96785974e-01,  6.32562526e-03, -7.98605583e-02],
                            [-6.28871776e-03,  9.99979971e-01,  7.13655225e-04],
                            [ 7.98634731e-02, -2.09141007e-04,  9.96805789e-01]])],
                [np.array([[ 9.97862224e-01,  5.95414270e-03, -6.50809498e-02],
                            [-5.88375907e-03,  9.99981880e-01,  1.27308988e-03],
                            [ 6.50873507e-02, -8.87447672e-04,  9.97879176e-01]])],
                [np.array([[0.997864, 0.006056, -0.065046],
                            [-0.006077, 0.999982, -0.000129],
                            [0.065044, 0.000524, 0.997882]])],
                [np.array([[0.997695, 0.005950, -0.067591],
                            [-0.005967, 0.999982, -0.000053],
                            [0.067590, 0.000456, 0.997713]])]]


Rot_list_4_p =  [[np.array([[0.999666, 0.002260, -0.025758],
                            [-0.002284, 0.999997, -0.000921],
                            [0.025756, 0.000979, 0.999668]])],
                [np.array([[0.998905, 0.007131, -0.046242],
                            [-0.009381, 0.998773, -0.048623],
                            [0.045838, 0.049004, 0.997746]])],
                [np.array([[0.997706, 0.006117, -0.067425],
                            [-0.007153, 0.999860, -0.015136],
                            [0.067323, 0.015583, 0.997610]])],
                [np.array([[0.998166, 0.005815, -0.060255],
                            [-0.005915, 0.999981, -0.001477],
                            [0.060246, 0.001831, 0.998182]])],
                [np.array([[0.998106, 0.006102, -0.061222],
                            [-0.006055, 0.999981, 0.000960],
                            [0.061227, -0.000587, 0.998124]])],
                [np.array([[0.998134, 0.005656, -0.060797],
                            [-0.006071, 0.999959, -0.006651],
                            [0.060757, 0.007008, 0.998128]])]]

# %%
Trns_list_2_p =  [[np.array([[-486.148518],
                            [7.986519],
                            [-349.481345]])],
                 [np.array([[-480.150365],
                            [-1.032461],
                            [-18.354234]])],
                 [np.array([[-475.604731],
                            [-2.995716],
                            [-9.700418]])],
                 [np.array([[-481.395487],
                            [-1.101631],
                            [-1.375279]])],
               [np.array([[-471.054816],
                            [-1.084550],
                            [-21.705676]])],
               [np.array([[-469.311981],
                            [-1.587343],
                            [-21.457134]])]]

Trns_list_3_p =  [[np.array([[-470.30484852],
                            [   1.12431283],
                            [ -24.95595177]])],
                 [np.array([[-473.01852902],
                            [   0.81341954],
                            [ -22.17573026]])],
                 [np.array([[-474.06210272],
                            [   1.62292259],
                            [ -21.70802313]])],
                 [np.array([[-4.74675869e+02],
                            [ 3.59611944e-01],
                            [-1.90589588e+01]])],
               [np.array([[-476.675004],
                            [0.583177],
                            [-15.308127]])],
               [np.array([[-476.303097],
                            [0.952368],
                            [-18.988435]])]]

Trns_list_4_p =  [[np.array([[-485.812480],
                            [-10.814819],
                            [448.155227]])],
                 [np.array([[-489.744803],
                            [10.434341],
                            [-51.906103]])],
                 [np.array([[-458.916068],
                            [-10.625318],
                            [55.431489]])],
                 [np.array([[-432.318535],
                            [-4.379498],
                            [110.675815]])],
               [np.array([[-416.329781],
                            [-10.541641],
                            [112.093923]])],
               [np.array([[-430.929996],
                            [2.312992],
                            [-380.822166]])]]

# %%
P_L_2_list_p = []
P_R_2_list_p = []

for i in range(len(ret_R_list_2_p)):
    R1,R2,P_L_est,P_R_est,Q,roi_left,roi_right = cv2.stereoRectify(new_mtxL_list_2_p[i][0], ret_L_list_2_p[i][0], new_mtxR_list_2_p[i][0], ret_R_list_2_p[i][0], (image_size[0],image_size[1]), Rot_list_2_p[i][0], Trns_list_2_p[i][0],flags = cv2.CALIB_ZERO_DISPARITY)
    P_L_2_list_p.append(P_L_est)
    P_R_2_list_p.append(P_R_est)

P_L_3_list_p = []
P_R_3_list_p = []

for i in range(len(ret_R_list_3_p)):
    R1,R2,P_L_est,P_R_est,Q,roi_left,roi_right = cv2.stereoRectify(new_mtxL_list_3_p[i][0], ret_L_list_3_p[i][0], new_mtxR_list_3_p[i][0], ret_R_list_3_p[i][0], (image_size[0],image_size[1]), Rot_list_3_p[i][0], Trns_list_3_p[i][0],flags = cv2.CALIB_ZERO_DISPARITY)
    P_L_3_list_p.append(P_L_est)
    P_R_3_list_p.append(P_R_est)

P_L_4_list_p = []
P_R_4_list_p = []

for i in range(len(ret_R_list_4_p)):
    R1,R2,P_L_est,P_R_est,Q,roi_left,roi_right = cv2.stereoRectify(new_mtxL_list_4_p[i][0], ret_L_list_4_p[i][0], new_mtxR_list_4_p[i][0], ret_R_list_4_p[i][0], (image_size[0],image_size[1]), Rot_list_4_p[i][0], Trns_list_4_p[i][0],flags = cv2.CALIB_ZERO_DISPARITY)
    P_L_4_list_p.append(P_L_est)
    P_R_4_list_p.append(P_R_est)

# %% [markdown]
# ## Centroid calculation
# Calculate from image using OpenCV

# %%
# Read image
nameimg = "../Thesis/distances/new/left_noinfi_20/left_init_"
# number of images
# list
circle_L = []





for i in range(9,10,1):
    img_name = (str(nameimg)+ str(i)+".png")
    print(img_name)
    img = cv2.imread(img_name, cv2.IMREAD_COLOR)
    # shape
    x = img.shape[0]
    y = img.shape[1]
    h = 200
    w = 700
    img_cut = img[0:x-300,600:y-200]
    



    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    img_shape = gray.shape
    gray_resize = cv2.resize(gray,[int(img_shape[1]*0.6),int(img_shape[0]*0.6)])


    # Blur using 27 * 27 kernel.
    gray_blurred = cv2.GaussianBlur(gray, (13,13),0)
    #
    image_thresh = cv2.threshold(gray_blurred,130,255,cv2.THRESH_BINARY)[1]
    # apply canny edge
    #image = cv2.Canny(gray_blurred, 0, 70)

    #cv2.imshow("gray_blurred",gray_blurred)
    #cv2.imshow("threshold",image_thresh)
    #cv2.waitKey(0)
    #cv2.destroyAllWindows()

    # Apply Hough transform on the blurred image.
    detected_circles = cv2.HoughCircles(image_thresh, 
               cv2.HOUGH_GRADIENT, 1, 100, param1 = 70,
               param2 = 15, minRadius = 0, maxRadius = 100)



    # Draw circles that are detected.
    if detected_circles is not None:
    
        # Convert the circle parameters a, b and r to integers.
        detected_circles = np.uint16(np.around(detected_circles))
        print(detected_circles.shape)
        for pt in detected_circles[0,:1,:]:
            a, b, r = pt[0], pt[1], pt[2]
            circle_L.append([a,b,r])
            print(a,b)
    
            # Draw the circumference of the circle.
            cv2.circle(image_thresh, (a, b), r, (0,0, 255), 3)
            # Draw a small circle (of radius 1) to show the center.
            cv2.circle(image_thresh, (a, b), 1, (0, 0, 255), 3)
            cv2.imshow("Detected Circle", image_thresh)
            cv2.circle(img, (a, b), r, (0,0, 255), 3)
            # Draw a small circle (of radius 1) to show the center.
            cv2.circle(img, (a, b), 1, (0, 0, 255), 3)
            cv2.imshow("Detected Circle", image_thresh)
            cv2.imshow("Decected circle color",img)


            k = cv2.waitKey(0) & 0xFF
            #print(k)
            if k == 27:  # close on ESC key
                cv2.destroyAllWindows()
                
                

circle_L_arr = np.asarray(circle_L,dtype = np.float64)
# Out:
# ../Thesis/distances/new/left_noinfi_20/left_init_9.png
# (1, 33, 3)
# 1054 542

# %%
# Read image
nameimg = "../Thesis/distances/new/right_noinfi_20/right_init_"
# number of images
# list
circle_R = []





for i in range(9,10,1):
    img_name = (str(nameimg)+ str(i)+".png")
    print(img_name)
    img = cv2.imread(img_name, cv2.IMREAD_COLOR)
    # shape
    x = img.shape[0]
    y = img.shape[1]
    h = 200
    w = 700
    img_cut = img[0:x-300,600:y-200]
    



    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    img_shape = gray.shape
    gray_resize = cv2.resize(gray,[int(img_shape[1]*0.6),int(img_shape[0]*0.6)])


    # Blur using 27 * 27 kernel.
    gray_blurred = cv2.GaussianBlur(gray, (5,5),0)
    #
    image_thresh = cv2.threshold(gray_blurred,120,255,cv2.THRESH_BINARY)[1]
    # apply canny edge
    #image = cv2.Canny(gray_blurred, 0, 70)

    #cv2.imshow("gray_blurred",gray_blurred)
    #cv2.imshow("threshold",image_thresh)
    #cv2.waitKey(0)
    #cv2.destroyAllWindows()

    # Apply Hough transform on the blurred image.
    detected_circles = cv2.HoughCircles(image_thresh, 
               cv2.HOUGH_GRADIENT, 1, 100, param1 = 70,
               param2 = 15, minRadius = 0, maxRadius = 100)


    # Draw circles that are detected.
    if detected_circles is not None:
    
        # Convert the circle parameters a, b and r to integers.
        detected_circles = np.uint16(np.around(detected_circles))
        print(detected_circles.shape)
        for pt in detected_circles[0,:1,:]:
            a, b, r = pt[0], pt[1], pt[2]
            circle_R.append([a,b,r])
            print(a,b)
    
            # Draw the circumference of the circle.
            cv2.circle(image_thresh, (a, b), r, (0,0, 255), 3)
            # Draw a small circle (of radius 1) to show the center.
            cv2.circle(image_thresh, (a, b), 1, (0, 0, 255), 3)
            cv2.imshow("Detected Circle", image_thresh)
            cv2.circle(img, (a, b), r, (0,0, 255), 3)
            # Draw a small circle (of radius 1) to show the center.
            cv2.circle(img, (a, b), 1, (0, 0, 255), 3)
            cv2.imshow("Detected Circle", image_thresh)
            cv2.imshow("Decected circle color",img)


            k = cv2.waitKey(0) & 0xFF
            #print(k)
            if k == 27:  # close on ESC key
                cv2.destroyAllWindows()
circle_R_arr = np.asarray(circle_R, dtype = np.float64)
# Out:
# ../Thesis/distances/new/right_noinfi_20/right_init_9.png
# (1, 31, 3)
# 888 592

# %%
circle_L_2_20 = [[1264, 498],
                [1182, 556],
                [1158, 544],
                [1096, 546],
                [1072, 548],
                [1054, 550],
                [1038, 544],
                [1044, 548],
                [1042, 542],
                [1054, 542]]

circle_R_2_20 = [[524, 548],
                [670, 604],
                [762, 594],
                [772, 596],
                [796, 598],
                [814, 600],
                [822, 594],
                [848, 598],
                [862, 592],
                [888, 592]]

circle_L_2_45 = [[1406, 526],
                [1278, 558],
                [1186, 560],
                [1130, 554],
                [1110, 542],
                [1086, 544],
                [1072, 538],
                [1072, 540],
                [1066, 538],
                [1080, 538]]

circle_R_2_45 = [[650, 574],
                [762, 608],
                [792, 608],
                [806, 604],
                [836, 592],
                [844, 594],
                [856, 588],
                [878, 590],
                [888, 588],
                [914, 588]]


circle_L_2_80 = [[1306, 480],
                [1198, 538],
                [1144, 538],
                [1114, 536],
                [1072, 528],
                [1064, 536],
                [1058, 542],
                [1060, 538],
                [1050, 538],
                [1058, 536]]

circle_R_2_80 = [[558, 528],
                [678, 586],
                [746, 588],
                [790, 586],
                [798, 580],
                [824, 586],
                [844, 592],
                [866, 590],
                [870, 588],
                [892, 588]]

circle_L_2_125 = [[1330, 602],
                [1264, 590],
                [1196, 586],
                [1118, 582],
                [1102, 568],
                [1082, 564],
                [1026, 558],
                [1050, 540],
                [1062, 550],
                [1064,546]]           

circle_R_2_125 = [[588, 652],
                [754, 640],
                [808, 638],
                [800, 632],
                [828, 618],
                [846, 616],
                [812, 608],
                [852, 590],
                [882, 600],
                [898, 598]]


circle_L_2_180 = [[1274, 488],
                 [1206, 550],
                 [1138, 536],
                 [1112, 534],
                 [1090, 528],
                 [1068, 534],
                 [1044, 528],
                 [1024, 534],
                 [1042, 538],
                 [1060, 536]]

circle_R_2_180 = [[524, 538],
                  [694, 600],
                  [744, 586],
                  [790, 582],
                  [816, 580],
                  [828, 586],
                  [828, 578],
                  [830, 584],
                  [864, 588],
                  [892, 584]]



circle_or_2_L_20 = np.array(circle_L_2_20,dtype = np.float64)
circle_or_2_R_20 = np.array(circle_R_2_20,dtype = np.float64)
circle_or_2_L_45 = np.array(circle_L_2_45,dtype = np.float64)
circle_or_2_R_45 = np.array(circle_R_2_45,dtype = np.float64)
circle_or_2_L_80 = np.array(circle_L_2_80,dtype = np.float64)
circle_or_2_R_80 = np.array(circle_R_2_80,dtype = np.float64)
circle_or_2_L_125 = np.array(circle_L_2_125,dtype = np.float64)
circle_or_2_R_125 = np.array(circle_R_2_125,dtype = np.float64)
circle_or_2_L_180 = np.array(circle_L_2_180,dtype = np.float64)
circle_or_2_R_180 = np.array(circle_R_2_180,dtype = np.float64)

# %%
X_est_arr_20 = []
X_est_arr_45 = []
X_est_arr_80 = []
X_est_arr_125  =  []
X_est_arr_180  =  []


for i in range(len(circle_or_2_R_20)):
    XestOpenCV_2_20= cv2.triangulatePoints(P_L_2_list_p[1],P_R_2_list_p[1], circle_or_2_L_20[i], circle_or_2_R_20[i])
    
    X_est_arr_20.append(XestOpenCV_2_20/XestOpenCV_2_20[3])


for i in range(len(circle_or_2_R_45)):
    XestOpenCV_2_45= cv2.triangulatePoints(P_L_2_list_p[2],P_R_2_list_p[2], circle_or_2_L_45[i], circle_or_2_R_45[i])
    
    X_est_arr_45.append(XestOpenCV_2_45/XestOpenCV_2_45[3])


for i in range(len(circle_or_2_R_80)):
    XestOpenCV_2_80= cv2.triangulatePoints(P_L_2_list_p[3],P_R_2_list_p[3], circle_or_2_L_80[i], circle_or_2_R_80[i])
    
    X_est_arr_80.append(XestOpenCV_2_80/XestOpenCV_2_80[3])


for i in range(len(circle_or_2_R_125)):
    XestOpenCV_2_125= cv2.triangulatePoints(P_L_2_list_p[4],P_R_2_list_p[4], circle_or_2_L_125[i], circle_or_2_R_125[i])
    
    X_est_arr_125.append(XestOpenCV_2_125/XestOpenCV_2_125[3])


for i in range(len(circle_or_2_R_180)):
    XestOpenCV_180= cv2.triangulatePoints(P_L_2_list_p[5],P_R_2_list_p[5], circle_or_2_L_180[i], circle_or_2_R_180[i])
    
    X_est_arr_180.append(XestOpenCV_180/XestOpenCV_180[3])

# %%
chessboards = [X_est_arr_80,X_est_arr_125,X_est_arr_180]
X_arr_est_noinfi_phy = np.zeros((len(chessboards),10,4,1))

for i,value in  enumerate(chessboards):
    X_arr_est_noinfi_phy[i,:,:,:] =  value

# %%
# from 1 meter to 300 meters in steps of 10 meters
zdistance = np.arange(2000,12000,1000)

# %%
#estError_20_distance
relative_Error_2_Z = np.zeros((X_arr_est_noinfi_phy.shape[0],zdistance.shape[0]))
Error_2_abs_Z = np.zeros((X_arr_est_noinfi_phy.shape[0],zdistance.shape[0]))

for j in range(Error_2_abs_Z.shape[0]):
    for i in range(Error_2_abs_Z.shape[1]):
        relative_Error_2_Z[j,i] = np.abs(X_arr_est_noinfi_phy[j,i,2,0]-zdistance[i])/(zdistance[i])*100
        Error_2_abs_Z[j,i] = np.abs(X_arr_est_noinfi_phy[j,i,2,0]-zdistance[i])

# %%
X_arr_est_noinfi_phy[j,i,2,0]
# Out:
# 7199.785494543844

# %%
np.save("E_err2_p_noinfi_phy.npy",Error_2_abs_Z)
np.save("relative_Error_2_Z_noinfi_phy.npy",relative_Error_2_Z)
np.save("X_est_arr_2_noinfi_phy.npy",X_arr_est_noinfi_phy)

# %% [markdown]
# ## Triangulation error vs. distance
# Correlate the triangulation error according to the distance of the spot.
# - Project the spot from 1:10:300 meters
# - having the ideal projection matrixes of the stereo cameras, retrieve the 2D coordinates
# - Having the 2D coordinates, triangulate the point using the projection matrixes obtained from calibration at 320 meters
# - Plot the results

# %%
# from 1 meter to 300 meters in steps of 10 meters
zdistance = np.arange(0,320000,1000)
zdistance[0] = 1000
xdistance = np.ones((zdistance.shape[0],))*250
ydistance = np.ones((zdistance.shape[0],))*100
X =np.array([xdistance,ydistance,zdistance]).T

x_arr_L, X_arr_L, E_L, K_L,P_L = get_image_points(X,PX,PY,thetax=THETA_X_L,thetay = THETA_Y_L,thetaz = THETA_Z_L,trans_x= -C_L[0],trans_y= -C_L[1],trans_z= -C_L[2],F = F,mx = (1/pixel_width),my =(1/pixel_width))
x_arr_R, X_arr_R, E_R, K_R,P_R = get_image_points(X,PX,PY,thetax = THETA_X_R,thetay = THETA_Y_R, thetaz = THETA_Z_R,trans_x= -C_R[0],trans_y= -C_R[1],trans_z= -C_R[2],F = F,mx = (1/pixel_width),my =(1/pixel_width))

# %%
n_distance = len(zdistance)
n_corners = chess_dimx*chess_dimy
len_chess = len(ret_L_list_2_p)

XestOpenCV_2 = np.zeros((len_chess,n_distance,4,1))
Xoriginal_2 = np.zeros((len_chess,n_distance,4,1))


estError_2_distance = np.zeros((len_chess,n_distance,1))


X_est_arr_2 = np.zeros((len_chess,n_distance,4,1))
X_org_arr_2 = np.zeros((len_chess,n_distance,4,1))



for i in range(len(ret_R_list_2_p)):
    for j in range(len(x_arr_R)):
        # 2 meters
        XestOpenCV_2[i,j,:,:] = cv2.triangulatePoints(P_L_2_list_p[i],P_R_2_list_p[i], x_arr_L[j], x_arr_R[j])
        Xoriginal_2[i,j,:,:] =  cv2.triangulatePoints(P_L_original_p[i],P_R_original_p[i],x_arr_L[j], x_arr_R[j])

        X_est_arr_2[i,j,:,:] = XestOpenCV_2[i,j,:,:]/XestOpenCV_2[i,j,-1,:]
        X_org_arr_2[i,j,:,:] = Xoriginal_2[i,j,:,:]/Xoriginal_2[i,j,-1,:]

        estError_2_distance[i,j,:] = np.sqrt(np.sum(np.square(X_est_arr_2[i,j,:3,:]-X_org_arr_2[i,j,:3,:])))

# %%
X_est_arr_2.shape
# Out:
# (6, 320, 4, 1)

# %%
estError_2_distance.shape
# Out:
# (6, 320, 1)

# %%
X_arr_est_phy_f8 = np.load("x_arr_est_phy_f8.npy")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# c:\Users\UX550\OneDrive - Universidade de Aveiro\Documentos\5º ANO\calibration\4.3.1 Circle Board distance calculator.ipynb Cell 32 in <module>
# ----> <a href='vscode-notebook-cell:/c%3A/Users/UX550/OneDrive%20-%20Universidade%20de%20Aveiro/Documentos/5%C2%BA%20ANO/calibration/4.3.1%20Circle%20Board%20distance%20calculator.ipynb#X35sZmlsZQ%3D%3D?line=0'>1</a> X_arr_est_phy_f8 = np.load("x_arr_est_phy_f8.npy")
#
# File c:\Users\UX550\AppData\Local\Programs\Python\Python38\lib\site-packages\numpy\lib\npyio.py:407, in load(file, mmap_mode, allow_pickle, fix_imports, encoding)
#     405     own_fid = False
#     406 else:
# --> 407     fid = stack.enter_context(open(os_fspath(file), "rb"))
#     408     own_fid = True
#     410 # Code to distinguish from NumPy binary files and pickles.
#
# FileNotFoundError: [Errno 2] No such file or directory: 'x_arr_est_phy_f8.npy'

# %%
E_err2_ideal_lst  = []
E_err2_infi_lst = []
E_err2_noinfi_lst = []

for i in range(X_arr_est_phy.shape[0]):
        E_err2_ideal_lst.append( (X_est_arr_2[i,2:12,2]-zdistance[2:12].reshape(10,1)))
        E_err2_infi_lst.append((X_arr_est_phy_f8[i,:,2]-zdistance[2:12].reshape(10,1)))
        E_err2_noinfi_lst.append((X_arr_est_phy[i,:,2]-zdistance[2:12].reshape(10,1)))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\UX550\OneDrive - Universidade de Aveiro\Documentos\5º ANO\calibration\4.3.1 Circle Board distance calculator.ipynb Cell 33 in <module>
#       <a href='vscode-notebook-cell:/c%3A/Users/UX550/OneDrive%20-%20Universidade%20de%20Aveiro/Documentos/5%C2%BA%20ANO/calibration/4.3.1%20Circle%20Board%20distance%20calculator.ipynb#X36sZmlsZQ%3D%3D?line=1'>2</a> E_err2_infi_lst = []
#       <a href='vscode-notebook-cell:/c%3A/Users/UX550/OneDrive%20-%20Universidade%20de%20Aveiro/Documentos/5%C2%BA%20ANO/calibration/4.3.1%20Circle%20Board%20distance%20calculator.ipynb#X36sZmlsZQ%3D%3D?line=2'>3</a> E_err2_noinfi_lst = []
# ----> <a href='vscode-notebook-cell:/c%3A/Users/UX550/OneDrive%20-%20Universidade%20de%20Aveiro/Documentos/5%C2%BA%20ANO/calibration/4.3.1%20Circle%20Board%20distance%20calculator.ipynb#X36sZmlsZQ%3D%3D?line=4'>5</a> for i in range(X_arr_est_phy.shape[0]):
#       <a href='vscode-notebook-cell:/c%3A/Users/UX550/OneDrive%20-%20Universidade%20de%20Aveiro/Documentos/5%C2%BA%20ANO/calibration/4.3.1%20Circle%20Board%20distance%20calculator.ipynb#X36sZmlsZQ%3D%3D?line=5'>6</a>         E_err2_ideal_lst.append( (X_est_arr_2[i,2:12,2]-zdistance[2:12].reshape(10,1)))
#       <a href='vscode-notebook-cell:/c%3A/Users/UX550/OneDrive%20-%20Universidade%20de%20Aveiro/Documentos/5%C2%BA%20ANO/calibration/4.3.1%20Circle%20Board%20distance%20calculator.ipynb#X36sZmlsZQ%3D%3D?line=6'>7</a>         E_err2_infi_lst.append((X_arr_est_phy_f8[i,:,2]-zdistance[2:12].reshape(10,1)))
#
# NameError: name 'X_arr_est_phy' is not defined

# %%
E_err2_ideal_arr = np.array(E_err2_ideal_lst).reshape(5,10)
E_err2_infi_arr = np.array(E_err2_infi_lst).reshape(5,10)
E_err2_noinfi_arr = np.array(E_err2_noinfi_lst).reshape(5,10)

# %%
E_err2_ideal_percent = np.zeros((5,10))
E_err2_infi_percent = np.zeros((5,10))
E_err2_noinfi_percent = np.zeros((5,10))

for i in range(E_err2_noinfi_arr.shape[0]):
    for counter,inume in enumerate(zdistance[2:12]):
        E_err2_ideal_percent[i,counter] = np.abs(E_err2_ideal_arr[i,counter]/inume*100)
        E_err2_infi_percent[i,counter] = np.abs(E_err2_infi_arr[i,counter]/inume*100)
        E_err2_noinfi_percent[i,counter] = np.abs(E_err2_noinfi_arr[i,counter]/inume*100)

# %%
E_err2_infi_percent.shape
# Out:
# (5, 10)

# %%
np.save("E_err2_p_noinfi_phy.npy",E_err2_noinfi_percent)
np.save("estError_2_distance_noinfi_phy.npy",estError_2_distance)

# %%
fig = plt.figure(figsize = (20,10))
ax = fig.add_subplot()

x_marker = np.linspace(10e-10,1e3,1000)
y_marker = np.ones((1000,1))
#ax.plot(x_marker,y_marker*0.001,'b--')

color_2 = ['black','firebrick','gold','chartreuse','darkcyan','m']
sub_2 = ["2 meters with 20 chessboards ideal points","2 meters with 45 chessboards ideal points","2 meters with 80 chessboards ideal points","2 meters with 125 chessboards ideal points","2 meters with 180 chessboards ideal points"]
color_3 = ['red','g','orange','c','darkblue','fuchsia']
sub_3 = ["2 meters with 20 chessboards experimental points (infi)","2 meters with 45 chessboards ideal points experimental points(infi)","2 meters with 80 chessboards ideal points experimental points(infi)","2 meters with 125 chessboards ideal points experimental points(infi)","2 meters with 180 chessboards ideal points experimental points(infi)"]
color_4 = ['darkslategray','brown','tomato','aqua','lime','y']
sub_4 = ["2 meters with 20 chessboards experimental points (no infi)","2 meters with 45 chessboards ideal points experimental points(no infi)","2 meters with 80 chessboards ideal points experimental points(no infi)","2 meters with 125 chessboards ideal points experimental points(no infi)","2 meters with 180 chessboards ideal points experimental points(no infi)"]

for i in range(E_err2_ideal_percent.shape[0]):

    #ax.plot(zdistance[2:12]/1000,E_err2_ideal_percent[i,:],color =  'b', marker = '^', label = "ideal")
    #ax.plot(zdistance[2:12]/1000,E_err2_ideal_percent[i,:],color = color_3[i],label = sub_2[i], marker = '*')
    ax.plot(zdistance[2:12]/1000,E_err2_noinfi_percent[i,:],color = color_4[i],label = sub_4[i], marker = 's')
    ax.plot(zdistance[2:12]/1000,E_err2_infi_percent[i,:],color = color_2[i],label  = sub_3[i], marker = 's')
    
ax.set_yscale('log')


ax.set_ylabel("Triangulation error percentage[%] ")
ax.set_title("Triangulation error[%]")
ax.set_xlabel("Distance [m]")
ax.legend()
ax.grid()

# %%
fig = plt.figure(figsize = (20,10))
ax = fig.add_subplot()

x_marker = np.linspace(10e-10,1e3,1000)
y_marker = np.ones((1000,1))
#ax.plot(x_marker,y_marker*0.001,'b--')

color_2 = ['black','firebrick','gold','chartreuse','darkcyan','m']
sub_2 = ["2 meters with 20 chessboards ideal points","2 meters with 45 chessboards ideal points","2 meters with 80 chessboards ideal points","2 meters with 125 chessboards ideal points","2 meters with 180 chessboards ideal points"]
color_3 = ['red','g','orange','c','darkblue','fuchsia']
sub_3 = ["2 meters with 20 chessboards experimental points (infi)","2 meters with 45 chessboards ideal points experimental points(infi)","2 meters with 80 chessboards ideal points experimental points(infi)","2 meters with 125 chessboards ideal points experimental points(infi)","2 meters with 180 chessboards ideal points experimental points(infi)"]
color_4 = ['darkslategray','brown','tomato','aqua','lime','y']
sub_4 = ["2 meters with 20 chessboards experimental points (no infi)","2 meters with 45 chessboards ideal points experimental points(no infi)","2 meters with 80 chessboards ideal points experimental points(no infi)","2 meters with 125 chessboards ideal points experimental points(no infi)","2 meters with 180 chessboards ideal points experimental points(no infi)"]

for i in range(X_arr_est_phy.shape[0]):

    ax.plot(zdistance[2:12]/1000,X_org_arr_2[1,2:12,2]/1000,color =  'b', marker = '^', label = "ideal")
    ax.plot(zdistance[2:12]/1000,X_est_arr_2[i,2:12,2]/1000,color = color_3[i],label = sub_2[i], marker = '*')
    ax.plot(zdistance[2:12]/1000,X_arr_est_phy[i,:,2]/1000,color = color_4[i],label = sub_4[i], marker = 's')
    ax.plot(zdistance[2:12]/1000,X_arr_est_phy_f8[i,:,2]/1000,color = color_2[i],label  = sub_3[i], marker = 's')
    #ax.plot(zdistance[2:12]/1000,zdistance[2:12]/1000)
    
#ax.set_yscale('log')


ax.set_ylabel("Triangulation distance[m] ")
ax.set_title("Triangulation error")
ax.set_xlabel("Distance [m]")
ax.legend()
ax.grid()

# %%
fig = plt.figure(figsize = (20,10))
ax = fig.add_subplot()

x_marker = np.linspace(10e-10,1e3,1000)
y_marker = np.ones((1000,1))
#ax.plot(x_marker,y_marker*0.001,'b--')

color_2 = ['black','firebrick','gold','chartreuse','darkcyan','m']
sub_2 = ["2 meters with 20 chessboards ideal points","2 meters with 45 chessboards ideal points","2 meters with 80 chessboards ideal points","2 meters with 125 chessboards ideal points","2 meters with 180 chessboards ideal points"]
color_3 = ['red','g','orange','c','darkblue','fuchsia']
sub_3 = ["2 meters with 20 chessboards experimental points (infi)","2 meters with 45 chessboards ideal points experimental points(infi)","2 meters with 80 chessboards ideal points experimental points(infi)","2 meters with 125 chessboards ideal points experimental points(infi)","2 meters with 180 chessboards ideal points experimental points(infi)"]
color_4 = ['darkslategray','brown','tomato','aqua','lime','y']
sub_4 = ["2 meters with 20 chessboards experimental points (no infi)","2 meters with 45 chessboards ideal points experimental points(no infi)","2 meters with 80 chessboards ideal points experimental points(no infi)","2 meters with 125 chessboards ideal points experimental points(no infi)","2 meters with 180 chessboards ideal points experimental points(no infi)"]

for i in range(X_arr_est_phy.shape[0]):

    ax.plot(zdistance[2:12]/1000,X_org_arr_2[1,2:12,2]/1000,color =  'b', marker = '^', label = "ideal")
    #ax.plot(zdistance[2:12]/1000,X_est_arr_2[i,2:12,2]/1000,color = color_3[i],label = sub_2[i], marker = '*')
    ax.plot(zdistance[2:12]/1000,X_arr_est_phy[i,:,2]/1000,color = color_4[i],label = sub_4[i], marker = 's')
    ax.plot(zdistance[2:12]/1000,X_arr_est_phy_f8[i,:,2]/1000,color = color_3[i],label = sub_3[i], marker = 's')
    #ax.plot(zdistance[2:12]/1000,zdistance[2:12]/1000)
    
#ax.set_yscale('log')


ax.set_ylabel("Triangulation distance[m] ")
ax.set_title("Triangulation error")
ax.set_xlabel("Distance [m]")
ax.legend()
ax.grid()
